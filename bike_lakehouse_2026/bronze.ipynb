# %% [markdown]
# # Reading and writing to a bronze table so the bronze layer will containe a 1:1 version of the raw data

# %%
insert_values = [
    #crm
    {
        "source": "crm",
        "path": "/Volumes/workspace/bronze/raw_sources/source_crm/cust_info.csv",
        "table_name": "bronze.crm_cust_info" 
    },
    {
        "source": "crm",
        "path": "/Volumes/workspace/bronze/raw_sources/source_crm/prd_info.csv",
        "table_name": "bronze.crm_prd_info"
    },
    {
        "source": "crm",
        "path": "/Volumes/workspace/bronze/raw_sources/source_crm/sales_details.csv",
        "table_name": "bronze.crm_sales_details"
    },
    #erp
    {
        "source": "erp",
        "path": "/Volumes/workspace/bronze/raw_sources/source_erp/CUST_AZ12.csv",
        "table_name": "bronze.erp_cust_az12"
    },
    {
        "source": "erp",
        "path": "/Volumes/workspace/bronze/raw_sources/source_erp/LOC_A101.csv",
        "table_name": "bronze.erp_loc_a101"
    },
    {
        "source": "erp",
        "path": "/Volumes/workspace/bronze/raw_sources/source_erp/PX_CAT_G1V2.csv",
        "table_name": "bronze.erp_erp_px_cat_g1v2"
    } 
]

# %%
for item in insert_values:
    df = (
        spark.read.option("header", "true")
          .option("inferSchema", "true")
          .csv(item["path"])
    )
    df.write.mode("overwrite").saveAsTable(item["table_name"])
